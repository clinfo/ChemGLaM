# %%
# !pip install -e .
# !conda install -c conda-forge rdkit=2024.9.2 -y

from chemglam import ChemGLaM, Config

config = Config("config/benchmark/davis_cv0_predict.json")
config.featurization_type = "token"
model = ChemGLaM.load_from_checkpoint(config.checkpoint_path, config=config, strict=False)

pred = model.predict("c1ccccc1", "MSACCC")
print("Interaction score = ", pred[0][0])
# Out:
# Obtaining file:///home/takutoyo/ChemGLaM_huggingface
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: chemglam
#     Found existing installation: chemglam 0.1
#     Uninstalling chemglam-0.1:
#       Successfully uninstalled chemglam-0.1
#   DEPRECATION: Legacy editable install of chemglam==0.1 from file:///home/takutoyo/ChemGLaM_huggingface (setup.py develop) is deprecated. pip 25.0 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457
#   Running setup.py develop for chemglam
# ...
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# ...
# Solving environment: done
#
# ...
